# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
data = pd.read_csv("data.csv", encoding="latin1")

print(data.columns)
# Out:
# /tmp/ipython-input-1302969766.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("data.csv", encoding="latin1")
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
x = data["no2"]

# Remove missing values
x = x.dropna().values

print("Total samples:", len(x))
# Out:
# Total samples: 419509

# %%
r = 102303495

ar = 0.05 * (r % 7)
br = 0.3 * ((r % 5) + 1)

print(ar, br)
# Out:
# 0.15000000000000002 1.2

# %%
z = x + ar * np.sin(br * x)

# %%
mu = np.mean(z)
sigma = np.std(z)

print("mu =", mu)
print("sigma =", sigma)
# Out:
# mu = 25.806338519611327
# sigma = 18.505894213391887

# %%
lam = 1 / (2 * sigma**2)
lam
# Out:
# np.float64(0.0014599899081690275)

# %%
c = 1 / np.sqrt(2 * np.pi * sigma**2)
c
# Out:
# np.float64(0.02155757921239688)

# %%
mu = np.mean(z)
sigma = np.std(z)

lam = 1 / (2 * sigma**2)
c = 1 / np.sqrt(2 * np.pi * sigma**2)

print("\nFINAL ANSWERS")
print("mu =", mu)
print("lambda =", lam)
print("c =", c)
# Out:
# FINAL ANSWERS
# mu = 25.806338519611327
# lambda = 0.0014599899081690275
# c = 0.02155757921239688
